# %% [markdown]
# # Verificación de los datasets
#
# ## Objetivo: Queremos determinar si existen diferencias importantes entre:
#
# - El dataset ya trabajado en la 1ra etapa (TelecomX_Data_Cleaned.csv)
# - El dataset limpio de referencia proporcionado por Alura (telecom_x_churn_tratado.csv)
#
# La comparación puede abordar:
#
# Columnas presentes en uno y no en el otro
#
# Tipos de datos
#
# Nulos
#
# Distribución de variables principales
#
# Valores únicos de categorías
#
# Tamaño y balance de target (Churn)

# %%
import pandas as pd

url_my_ds = 'https://raw.githubusercontent.com/LenninTemoche/Challenge-TelecomX-Alura-One-DS/refs/heads/main/TelecomX_Data_Cleaned.csv'
url_ds_tratado = 'datos_tratados.csv'

df_my_ds = pd.read_csv(url_my_ds)
df_ds_tratado = pd.read_csv(url_ds_tratado)

print('Dataset generado:', df_my_ds.shape)
print('Dataset tratado:', df_ds_tratado.shape)

# %%
df_my_ds.info()

df_ds_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   object
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
# Eliminar prefijos antes del punto
df_ds_tratado.columns = df_ds_tratado.columns.str.split('.').str[-1]

print("Columnas después de limpiar prefijos:\n")
df_ds_tratado.info()
# Out:
# Columnas después de limpiar prefijos:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customerID            7043 non-null   object
#  1   Churn                 7043 non-null   object
#  2   gender                7043 non-null   object
#  3   SeniorCitizen         7043 non-null   int64
#  4   Partner               7043 non-null   object
#  5   Dependents            7043 non-null   object
#  6   tenure                7043 non-null   int64
#  7   PhoneService          7043 non-null   object
#  8   MultipleLines         7043 non-null   object
#  9   InternetService       7043 non-null   object
#  10  OnlineSecurity        7043 non-null   object
#  11  OnlineBackup          7043 non-null   object
#  12  DeviceProtection      7043 non-null   object
#  13  TechSupport           7043 non-null   object
# ...

# %%
# Columnas que están en uno y no en el otro
cols_mio = set(df_my_ds.columns)
cols_trat = set(df_ds_tratado.columns)

solo_en_mio = cols_mio - cols_trat
solo_en_trat = cols_trat - cols_mio

print('Columnas solo en mi dataset:', solo_en_mio)
print('Columnas solo en dataset de referencia:', solo_en_trat)

print('\nColumnas compartidas:', cols_mio.intersection(cols_trat))
# Out:
# Columnas solo en mi dataset: {'daily_account', 'num_services'}
# Columnas solo en dataset de referencia: {'Churn_bin', 'PaperlessBilling_bin', 'Cuentas_Diarias'}
#
# Columnas compartidas: {'SeniorCitizen', 'InternetService', 'gender', 'Monthly', 'StreamingTV', 'OnlineBackup', 'Total', 'Contract', 'PaymentMethod', 'OnlineSecurity', 'TechSupport', 'StreamingMovies', 'customerID', 'PaperlessBilling', 'Dependents', 'tenure', 'DeviceProtection', 'Churn', 'Partner', 'PhoneService', 'MultipleLines'}

# %% [markdown]
# #### 🔹 Columnas solo presentes en el dataset propio
# - `daily_account`
# - `num_services`
#
# Estas variables corresponden a procesos de **feature engineering** realizados durante el análisis exploratorio:
# - `daily_account`: Transformación derivada del cargo mensual.
# - `num_services`: Conteo del número total de servicios contratados por cliente.
#
# ---
#
# #### 🔹 Columnas solo presentes en el dataset de referencia
# - `Churn_bin`
# - `PaperlessBilling_bin`
# - `Cuentas_Diarias`
#
# Observaciones:
# - `Cuentas_Diarias` es equivalente a `daily_account`, pero con diferente nombre.
# - `Churn_bin` y `PaperlessBilling_bin` son variables binarias generadas para facilitar el modelado predictivo.
#
# ---
#
# #### 🔹 Columnas compartidas (21 variables base)
#
# Ambos datasets coinciden en las variables estructurales principales del negocio, incluyendo:
#
# - Información del cliente (`gender`, `SeniorCitizen`, `Partner`, `Dependents`, `tenure`)
# - Servicios contratados
# - Información contractual
# - Cargos (`Monthly`, `Total`)
# - Variable objetivo (`Churn`)

# %% [markdown]
# ## Conclusiones
#
# - Ambos datasets parten de la misma estructura base.
# - Las diferencias se deben principalmente a enfoques distintos en la preparación de datos:
#   - El dataset propio prioriza **análisis exploratorio y creación de variables derivadas**.
#   - El dataset de referencia prioriza **binarización y preparación directa para modelado**.
# - No existen inconsistencias estructurales críticas.
# - La variable `Cuentas_Diarias` es equivalente a `daily_account`, por lo que ambas versiones pueden homologarse fácilmente.
#
# En conclusión, ambos datasets son coherentes entre sí y pueden alinearse sin pérdida de información relevante para la fase predictiva.

# %% [markdown]
# ## Dataset para modelado
